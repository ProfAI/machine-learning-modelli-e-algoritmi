# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAI/machine-learning-modelli-e-algoritmi/blob/main/1%20-%20L'algoritmo%20Gradient%20Descent/stochastic_fullbatch_minibatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stochastic, Mini Batch e Full Batch Gradient Descend

# %%
from time import time
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.metrics import log_loss
from sklearn.linear_model import SGDClassifier
from sklearn.utils import shuffle

# %%
X, Y = make_classification(n_samples=1250, n_features=4, n_informative=2, random_state=0)
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Stochastic Gradient Descend

# %%
epochs = 5

n_batches=X_train.shape[0]
batch_size = X_train.shape[0]/n_batches

classes = np.unique(Y_train)

sgd = SGDClassifier(loss="log")
sgd_losses = []

tick = time()

for epoch in range(epochs):
        X_shuffled, Y_shuffled = shuffle(X_train, Y_train)
        for batch in range(n_batches):
            batch_start = int(batch*batch_size)
            batch_end = int((batch+1)*batch_size)
            X_batch = X_shuffled[batch_start:batch_end,:]
            Y_batch = Y_shuffled[batch_start:batch_end]

            sgd.partial_fit(X_batch, Y_batch, classes=classes)
            loss = log_loss(Y_test, sgd.predict_proba(X_test),labels=classes)
            sgd_losses.append(loss)       
        print("Loss all'epoca %d = %.4f" % (epoch+1, loss))

print(f"Addestramento completato in {time()-tick:.2f} secondi")
# Out:
# Loss all'epoca 1 = 0.5619
# Loss all'epoca 2 = 0.8174
# Loss all'epoca 3 = 0.3384
# Loss all'epoca 4 = 0.2723
# Loss all'epoca 5 = 0.2783
# Addestramento completato in 6.07 secondi

# %%
plt.figure(figsize=(14,10))
plt.title("Stochastic Gradient Descend")
plt.xlabel("Iterazione")
plt.ylabel("Log-Loss")
plt.plot(sgd_losses)

# %% [markdown]
# ## Full Batch Gradient Descend

# %%
epochs = 200

n_batches=1

batch_size = X_train.shape[0]/n_batches

classes = np.unique(Y)

sgd = SGDClassifier(loss="log")
full_losses = []

tick = time()

for epoch in range(epochs):
        loss = 0.
        X_shuffled, Y_shuffled = shuffle(X_train, Y_train)
        for batch in range(n_batches):
            batch_start = int(batch*batch_size)
            batch_end = int((batch+1)*batch_size)
            X_batch = X_shuffled[batch_start:batch_end,:]
            Y_batch = Y_shuffled[batch_start:batch_end]

            sgd.partial_fit(X_batch, Y_batch, classes=classes)
            loss = log_loss(Y_test, sgd.predict_proba(X_test),labels=classes)
            full_losses.append(loss)       
        print("Loss all'epoca %d = %.4f" % (epoch+1, loss))

print(f"Addestramento completato in {time()-tick:.2f} secondi")
# Out:
# Loss all'epoca 1 = 0.7612
# Loss all'epoca 2 = 0.5540
# Loss all'epoca 3 = 0.4685
# Loss all'epoca 4 = 0.3281
# Loss all'epoca 5 = 0.8789
# Loss all'epoca 6 = 0.2056
# Loss all'epoca 7 = 0.2335
# Loss all'epoca 8 = 0.2183
# Loss all'epoca 9 = 0.2078
# Loss all'epoca 10 = 0.1582
# Loss all'epoca 11 = 0.1377
# Loss all'epoca 12 = 0.1289
# Loss all'epoca 13 = 0.2040
# Loss all'epoca 14 = 0.1273
# Loss all'epoca 15 = 0.1615
# Loss all'epoca 16 = 0.1143
# Loss all'epoca 17 = 0.1101
# Loss all'epoca 18 = 0.1112
# Loss all'epoca 19 = 0.1234
# Loss all'epoca 20 = 0.1531
# Loss all'epoca 21 = 0.1102
# Loss all'epoca 22 = 0.1109
# Loss all'epoca 23 = 0.1094
# Loss all'epoca 24 = 0.1170
# Loss all'epoca 25 = 0.1322
# Loss all'epoca 26 = 0.1120
# Loss all'epoca 27 = 0.1130
# Loss all'epoca 28 = 0.1196
# Loss all'epoca 29 = 0.1091
# Loss all'epoca 30 = 0.1104
# Loss all'epoca 31 = 0.1192
# Loss all'epoca 32 = 0.1185
# Loss all'epoca 33 = 0.1338
# Loss all'epoca 34 = 0.1065
# Loss all'epoca 35 = 0.1090
# Loss all'epoca 36 = 0.1077
# Loss all'epoca 37 = 0.1149
# Loss all'epoca 38 = 0.1137
# Loss all'epoca 39 = 0.1140
# Loss all'epoca 40 = 0.1162
# Loss all'epoca 41 = 0.1174
# Loss all'epoca 42 = 0.1159
# Loss all'epoca 43 = 0.1061
# Loss all'epoca 44 = 0.1062
# Loss all'epoca 45 = 0.1088
# Loss all'epoca 46 = 0.1089
# Loss all'epoca 47 = 0.1132
# Loss all'epoca 48 = 0.1108
# Loss all'epoca 49 = 0.1237
# Loss all'epoca 50 = 0.1281
# Loss all'epoca 51 = 0.1089
# Loss all'epoca 52 = 0.1137
# Loss all'epoca 53 = 0.1076
# Loss all'epoca 54 = 0.1122
# Loss all'epoca 55 = 0.1107
# Loss all'epoca 56 = 0.1085
# Loss all'epoca 57 = 0.1084
# Loss all'epoca 58 = 0.1084
# Loss all'epoca 59 = 0.1228
# Loss all'epoca 60 = 0.1102
# Loss all'epoca 61 = 0.1137
# Loss all'epoca 62 = 0.1299
# Loss all'epoca 63 = 0.1089
# Loss all'epoca 64 = 0.1088
# Loss all'epoca 65 = 0.1091
# Loss all'epoca 66 = 0.1130
# Loss all'epoca 67 = 0.1100
# Loss all'epoca 68 = 0.1100
# Loss all'epoca 69 = 0.1058
# Loss all'epoca 70 = 0.1079
# Loss all'epoca 71 = 0.1068
# Loss all'epoca 72 = 0.1086
# Loss all'epoca 73 = 0.1061
# Loss all'epoca 74 = 0.1070
# Loss all'epoca 75 = 0.1085
# Loss all'epoca 76 = 0.1094
# Loss all'epoca 77 = 0.1083
# Loss all'epoca 78 = 0.1054
# Loss all'epoca 79 = 0.1101
# Loss all'epoca 80 = 0.1109
# Loss all'epoca 81 = 0.1104
# Loss all'epoca 82 = 0.1091
# Loss all'epoca 83 = 0.1075
# Loss all'epoca 84 = 0.1080
# Loss all'epoca 85 = 0.1076
# Loss all'epoca 86 = 0.1057
# Loss all'epoca 87 = 0.1080
# Loss all'epoca 88 = 0.1056
# Loss all'epoca 89 = 0.1072
# Loss all'epoca 90 = 0.1081
# Loss all'epoca 91 = 0.1066
# Loss all'epoca 92 = 0.1080
# Loss all'epoca 93 = 0.1109
# Loss all'epoca 94 = 0.1088
# Loss all'epoca 95 = 0.1092
# Loss all'epoca 96 = 0.1065
# Loss all'epoca 97 = 0.1097
# Loss all'epoca 98 = 0.1237
# Loss all'epoca 99 = 0.1099
# Loss all'epoca 100 = 0.1064
# Loss all'epoca 101 = 0.1088
# Loss all'epoca 102 = 0.1061
# Loss all'epoca 103 = 0.1056
# Loss all'epoca 104 = 0.1076
# Loss all'epoca 105 = 0.1096
# Loss all'epoca 106 = 0.1062
# Loss all'epoca 107 = 0.1055
# Loss all'epoca 108 = 0.1168
# Loss all'epoca 109 = 0.1080
# Loss all'epoca 110 = 0.1088
# Loss all'epoca 111 = 0.1133
# Loss all'epoca 112 = 0.1073
# Loss all'epoca 113 = 0.1059
# Loss all'epoca 114 = 0.1078
# Loss all'epoca 115 = 0.1069
# Loss all'epoca 116 = 0.1093
# Loss all'epoca 117 = 0.1065
# Loss all'epoca 118 = 0.1063
# Loss all'epoca 119 = 0.1104
# Loss all'epoca 120 = 0.1091
# Loss all'epoca 121 = 0.1098
# Loss all'epoca 122 = 0.1053
# Loss all'epoca 123 = 0.1067
# Loss all'epoca 124 = 0.1058
# Loss all'epoca 125 = 0.1098
# Loss all'epoca 126 = 0.1056
# Loss all'epoca 127 = 0.1069
# Loss all'epoca 128 = 0.1070
# Loss all'epoca 129 = 0.1076
# Loss all'epoca 130 = 0.1058
# Loss all'epoca 131 = 0.1059
# Loss all'epoca 132 = 0.1056
# Loss all'epoca 133 = 0.1064
# Loss all'epoca 134 = 0.1060
# Loss all'epoca 135 = 0.1062
# Loss all'epoca 136 = 0.1065
# Loss all'epoca 137 = 0.1064
# Loss all'epoca 138 = 0.1071
# Loss all'epoca 139 = 0.1063
# Loss all'epoca 140 = 0.1108
# Loss all'epoca 141 = 0.1065
# Loss all'epoca 142 = 0.1062
# Loss all'epoca 143 = 0.1090
# Loss all'epoca 144 = 0.1081
# Loss all'epoca 145 = 0.1066
# Loss all'epoca 146 = 0.1066
# Loss all'epoca 147 = 0.1074
# Loss all'epoca 148 = 0.1065
# Loss all'epoca 149 = 0.1068
# Loss all'epoca 150 = 0.1062
# Loss all'epoca 151 = 0.1084
# Loss all'epoca 152 = 0.1073
# Loss all'epoca 153 = 0.1081
# Loss all'epoca 154 = 0.1059
# Loss all'epoca 155 = 0.1060
# Loss all'epoca 156 = 0.1070
# Loss all'epoca 157 = 0.1080
# Loss all'epoca 158 = 0.1061
# Loss all'epoca 159 = 0.1101
# Loss all'epoca 160 = 0.1067
# Loss all'epoca 161 = 0.1061
# Loss all'epoca 162 = 0.1097
# Loss all'epoca 163 = 0.1057
# Loss all'epoca 164 = 0.1059
# Loss all'epoca 165 = 0.1061
# Loss all'epoca 166 = 0.1061
# Loss all'epoca 167 = 0.1067
# Loss all'epoca 168 = 0.1065
# Loss all'epoca 169 = 0.1064
# Loss all'epoca 170 = 0.1096
# Loss all'epoca 171 = 0.1071
# Loss all'epoca 172 = 0.1067
# Loss all'epoca 173 = 0.1066
# Loss all'epoca 174 = 0.1064
# Loss all'epoca 175 = 0.1068
# Loss all'epoca 176 = 0.1117
# Loss all'epoca 177 = 0.1072
# Loss all'epoca 178 = 0.1060
# Loss all'epoca 179 = 0.1076
# Loss all'epoca 180 = 0.1062
# Loss all'epoca 181 = 0.1061
# Loss all'epoca 182 = 0.1090
# Loss all'epoca 183 = 0.1060
# Loss all'epoca 184 = 0.1126
# Loss all'epoca 185 = 0.1057
# Loss all'epoca 186 = 0.1056
# Loss all'epoca 187 = 0.1070
# Loss all'epoca 188 = 0.1060
# Loss all'epoca 189 = 0.1082
# Loss all'epoca 190 = 0.1063
# Loss all'epoca 191 = 0.1070
# Loss all'epoca 192 = 0.1077
# Loss all'epoca 193 = 0.1092
# Loss all'epoca 194 = 0.1072
# Loss all'epoca 195 = 0.1077
# Loss all'epoca 196 = 0.1073
# Loss all'epoca 197 = 0.1056
# Loss all'epoca 198 = 0.1056
# Loss all'epoca 199 = 0.1057
# Loss all'epoca 200 = 0.1055
# Addestramento completato in 0.51 secondi

# %% [markdown]
# Il GD è riuscito a convergere fornendo un buon risultato, vediamo il grafico della funzione di costo ad ogni iterazione ( in questo caso un iterazione corrisponde ad un'epoca )

# %%
plt.figure(figsize=(14,10))
plt.title("Gradient Descend")
plt.xlabel("Iterazione")
plt.ylabel("Log-Loss")
plt.plot(full_losses)

# %% [markdown]
# ## Mini Batch Gradient Descend

# %%
epochs = 50

n_batches=10

batch_size = X_train.shape[0]/n_batches

classes = np.unique(Y)

sgd = SGDClassifier(loss="log")
batch_losses = []

tick = time()

for epoch in range(epochs):
        X_shuffled, Y_shuffled = shuffle(X_train, Y_train)
        for batch in range(n_batches):
            batch_start = int(batch*batch_size)
            batch_end = int((batch+1)*batch_size)
            X_batch = X_shuffled[batch_start:batch_end,:]
            Y_batch = Y_shuffled[batch_start:batch_end]
            sgd.partial_fit(X_batch, Y_batch, classes=classes)
            loss = log_loss(Y_test, sgd.predict_proba(X_test),labels=classes)
            batch_losses.append(loss)       
        print("Loss all'epoca %d = %.4f" % (epoch+1, loss))

print(f"Addestramento completato in {time()-tick:.2f} secondi")
# Out:
# Loss all'epoca 1 = 1.0778
# Loss all'epoca 2 = 0.2806
# Loss all'epoca 3 = 0.4364
# Loss all'epoca 4 = 0.4306
# Loss all'epoca 5 = 0.3323
# Loss all'epoca 6 = 0.1522
# Loss all'epoca 7 = 0.2087
# Loss all'epoca 8 = 0.2112
# Loss all'epoca 9 = 0.1284
# Loss all'epoca 10 = 0.1777
# Loss all'epoca 11 = 0.1667
# Loss all'epoca 12 = 0.1413
# Loss all'epoca 13 = 0.1142
# Loss all'epoca 14 = 0.1134
# Loss all'epoca 15 = 0.1508
# Loss all'epoca 16 = 0.1374
# Loss all'epoca 17 = 0.1206
# Loss all'epoca 18 = 0.1069
# Loss all'epoca 19 = 0.1267
# Loss all'epoca 20 = 0.1199
# Loss all'epoca 21 = 0.1168
# Loss all'epoca 22 = 0.1231
# Loss all'epoca 23 = 0.2182
# Loss all'epoca 24 = 0.1215
# Loss all'epoca 25 = 0.1203
# Loss all'epoca 26 = 0.1420
# Loss all'epoca 27 = 0.1108
# Loss all'epoca 28 = 0.1164
# Loss all'epoca 29 = 0.1153
# Loss all'epoca 30 = 0.1118
# Loss all'epoca 31 = 0.1106
# Loss all'epoca 32 = 0.1080
# Loss all'epoca 33 = 0.1256
# Loss all'epoca 34 = 0.1096
# Loss all'epoca 35 = 0.1092
# Loss all'epoca 36 = 0.1120
# Loss all'epoca 37 = 0.1082
# Loss all'epoca 38 = 0.1124
# Loss all'epoca 39 = 0.1157
# Loss all'epoca 40 = 0.1481
# Loss all'epoca 41 = 0.1173
# Loss all'epoca 42 = 0.1063
# Loss all'epoca 43 = 0.1131
# Loss all'epoca 44 = 0.1131
# Loss all'epoca 45 = 0.1272
# Loss all'epoca 46 = 0.1138
# Loss all'epoca 47 = 0.1094
# Loss all'epoca 48 = 0.1083
# Loss all'epoca 49 = 0.1115
# Loss all'epoca 50 = 0.1062
# Addestramento completato in 0.88 secondi

# %%
plt.figure(figsize=(14,10))
plt.title("Batch Gradient Descend")
plt.xlabel("Iterazione")
plt.ylabel("Log-Loss")
plt.plot(batch_losses)

# %% [markdown]
# ## Il confronto
# Confrontiamo le oscillazioni della funzione di costo per Full Batch, Stochastic e Mini Batch Gradient Descend, mettendole su di uno stesso grafico

# %%
plt.figure(figsize=(14,10))
plt.plot(batch_losses, label="Batch")
plt.plot(sgd_losses, label="Stochastic")
plt.plot(full_losses,label="Full")
plt.xlim(xmin=0,xmax=200)
plt.legend()
plt.show()
